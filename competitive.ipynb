# %% [markdown]
# <a href="https://colab.research.google.com/github/Hrudayesh-yaddala/Time-table/blob/main/competitive.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
df=pd.read_excel('geeks.xlsx')

# %%
# def binarysearch():
#   df.dropna(subset=['BINARY SEARCH'],inplace=True)
#   print(df['BINARY SEARCH'])
# def arrays():
#   df.dropna(subset=['Arrays'],inplace=True)
#   print(df['Arrays'])
# def strings():
#   df.dropna(subset=['STRINGS'],inplace=True)
#   print(df['STRINGS'])
# def dynamicprogramming():
#   df.dropna(subset=['DYNAMIC PROGRAMING'],inplace=True)
#   print(df['DYNAMIC PROGRAMING'])
# def greedy():
#   df.dropna(subset=['Greedy'],inplace=True) 
#   print(df['Greedy'])
# def tree():
#   df.dropna(subset=['TREE'],inplace=True)
#   print(df['TREE'])
# def graph():
#   df.dropna(subset=['GRAPH'],inplace=True)
#   print(df['GRAPH'])
# def heap():
#   df.dropna(subset=['HEAP'],inplace=True)
#   print(df['HEAP'])
# def linkedlist():
#   df.dropna(subset=['LINKED LIST'],inplace=True)
#   print(df['LINKED LIST'])
# def bfs():
#   df.dropna(subset=['BFS'],inplace=True)
#   print(df['BFS'])
# def dfs():
#   df.dropna(subset=['DFS'],inplace=True)
#   print(df['DFS'])
# def maths():
#   df.dropna(subset=['MATHS'],inplace=True)
#   print(df['MATHS'])
# def recursion():
#   df.dropna(subset=['RECURSION'],inplace=True)
#   print(df['RECURSION'])
# def twopointer():
#   df.dropna(subset=['TWO POINTER'],inplace=True)
#   print(df['TWO POINTER'])
# def stack():
#   df.dropna(subset=['STACK'],inplace=True)
#   print(df['STACK'])
# def design():
#   df.dropna(subset=['DESIGN'],inplace=True)
#   print(df['DESIGN'])
# def slidingwindow():
#   df.dropna(subset=['SLIDING WINDOW'],inplace=True)
#   print(df['SLIDING WINDOW'])

def result(Topic):
  df.dropna(subset=[Topic],inplace=True)
  df.index = np.arange(1, len(df) + 1)
  print(df[Topic])

result('BINARY SEARCH')
# Out:
# hello
# 1                                                  EASY
# 2                  https://leetcode.com/problems/sqrtx/
# 3          https://leetcode.com/problems/binary-search/
# 4     https://leetcode.com/problems/count-negative-n...
# 5     https://leetcode.com/problems/peak-index-in-a-...
# 6                                                MEDIUM
# 7     https://leetcode.com/problems/time-based-key-v...
# 8     https://leetcode.com/problems/search-in-rotate...
# 9                 https://leetcode.com/problems/powx-n/
# 10    https://leetcode.com/problems/find-first-and-l...
# 11     https://leetcode.com/problems/find-peak-element/
# 12    https://leetcode.com/problems/search-a-2d-matrix/
# 13    https://leetcode.com/problems/divide-two-integ...
# 14    https://leetcode.com/problems/capacity-to-ship...
# 15    https://leetcode.com/problems/minimum-limit-of...
# 16                                                 HARD
# 17    https://leetcode.com/problems/median-of-two-so...
# ...

# %%
# def leetcode():
  # binarysearch()
  # arrays()
  # strings()
  # dynamicprogramming()
  # greedy()
  # tree()
  # graph()
  # heap()
  # linkedlist()
  # bfs()
  # dfs()
  # maths()
  # recursion()
  # twopointer()
  # stack()
  # design()
  # slidingwindow()

# def geeksforgeeks():
  # binarysearch()
  # arrays()
  # strings()
  # dynamicprogramming()
  # greedy()
  # tree()
  # graph()
  # linkedlist()
  # bfs()
  # dfs()
  # maths()
# def codechef():
  # binarysearch()
  # arrays()
  # strings()
  # dynamicprogramming()
  # greedy()
  # tree()
  # graph()
  # linkedlist()
  # bfs()
  # dfs()
  # maths()
# def hackerearth():
  # binarysearch()
  # arrays()
  # strings()
  # dynamicprogramming()
  # greedy()
  # tree()
  # graph()
  # linkedlist()
  # bfs()
  # dfs()
  # maths()

# %%
# leetcode()
# geeksforgeeks()
# codechef()
# hackerearth()

# %%
leet_topics = {
    '1' : 'Arrays',
    '2' : 'RECURSION',
    '3' : 'DYNAMIC PROGRAMING',
    '4' : 'STRINGS',
    '5' : 'MATHS',
    '6' : 'GREEDY ',
    '7' : 'DFS',
    '8' : 'TREE',
    '9' : 'BINARY SEARCH',
    '10' : 'BFS',
    '11' : 'TWO POINTER',
    '12' : 'STACK',
    '13' : 'DESIGN',
    '14' : 'GRAPH',
    '15' : 'LINKED LIST',
    '16' : 'HEAP',
    '17' : 'SLIDING WINDOW'
}

geek_topics = {
    '1' : 'ARRAYS',
    '2' : 'STRINGS',
    '3' : '2D ARRAYS',
    '4' : 'SEARCHING AND SORTING',
    '5' : 'BACK TRACKING',
    '6' : 'LINKED LIST',
    '7' : 'STACKS AND QUEUES',
    '8' : 'GREEDY',
    '9' : 'BINARY TREES',
    '10' : 'BINARY SEARCH TREES',
    '11' : 'HEAPS AND HASHING',
    '12' : 'GRAPHS',
    '13' : 'TRIES',
    '14' : 'DYNAMIC PROGRAMMING',
    '15' : 'BIT MANIPULATION',
    '16' : 'SEGMENT TREES',
}

geeks_topics_msg = '''
1. Arrays
2. Strings
3. 2D Arrays
4. Searching and Sorting
5. Back Tracking
6. Linked List
7. Stacks and Queues
8. Greedy
9. Binary Trees
10. Binary Search Trees
11. Heaps and Hashing
12. Graphs
13. Tries
14. Dynamic Programming
15. Bit Manipulation
16. Segment Trees'''
